# %%
import torch
import import_ipynb # import another nbs like modules .py
from CycleGAN_dataset import HorseZebraDataset
import sys
from CycleGAN_utils import save_checkpoint, load_checkpoint
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
import CycleGAN_config as config
from tqdm import tqdm
from torchvision.utils import save_image
from CycleGAN_discriminator import Discriminator
from CycleGAN_generator import Generator


def train_fn(disc_H, disc_Z, gen_Z, gen_H, loader, opt_disc, opt_gen, L1, mse, d_scaler, g_scaler):
    loop = tqdm(loader, leave = True)
    
    for idx, (zebra, horse) in enumerate(loop):
        zebra = zebra.to(config.DEVICE)
        horse = horse.to(config.DEVICE)
        
        ### TRAIN DISCRIMINATORS H AND Z:
        with torch.cuda.amp.autocast():# to increase gpu speed and save memory
            fake_horse = gen_H(zebra)
            D_H_real = disc_H(horse)
            D_H_fake = disc_H(fake_horse.detach())
            D_H_real_loss = mse(D_H_real, torch.ones_like(D_H_real))
            D_H_fake_loss = mse(D_H_fake, torch.zeros_like(D_H_fake))
            D_H_loss = D_H_real_loss + D_H_fake_loss

            fake_zebra = gen_Z(horse)
            D_Z_real = disc_Z(zebra)
            D_Z_fake = disc_Z(fake_zebra.detach())
            D_Z_real_loss = mse(D_Z_real, torch.ones_like(D_Z_real))
            D_Z_fake_loss = mse(D_Z_fake, torch.zeros_like(D_Z_fake))
            D_Z_loss = D_Z_real_loss + D_Z_fake_loss
            
            # put it togheter
            D_loss = (D_H_loss + D_Z_loss)/2
            
        opt_disc.zero_grad()
        d_scaler.scale(D_loss).backward()
        d_scaler.step(opt_disc)
        d_scaler.update()


        ### TRAIN GENERATORS H AND Z:
        with torch.cuda.amp.autocast(): # to increase gpu speed and save memory
            # adversarial loss for both generators
            D_H_fake = disc_H(fake_horse)
            D_Z_fake = disc_Z(fake_zebra)
            loss_G_H = mse(D_H_fake, torch.ones_like(D_H_fake))
            loss_G_Z = mse(D_Z_fake, torch.ones_like(D_Z_fake))
            
            # cycle loss
            cycle_zebra = gen_Z(fake_horse)
            cycle_horse = gen_H(fake_zebra)
            cycle_zebra_loss = L1(zebra, cycle_zebra)
            cycle_horse_loss = L1(horse, cycle_horse)
            
            #identity loss
            identity_zebra = gen_Z(zebra)
            identity_horse = gen_H(horse)
            identity_zebra_loss = L1(zebra, identity_zebra)
            identity_horse_loss = L1(horse, identity_horse)
        
            # add all together
            G_loss = (
                loss_G_Z
                + loss_G_H
                + cycle_zebra_loss * config.LAMBDA_CYCLE
                + cycle_horse_loss * config.LAMBDA_CYCLE
                + identity_horse_loss * config.LAMBDA_IDENTITY # note: we dont use identity loss, because the paper only use in some cases son  LAMBDA_IDENTITY == 0
                + identity_zebra_loss * config.LAMBDA_IDENTITY
            )
            
        opt_gen.zero_grad()
        g_scaler.scale(G_loss).backward()
        g_scaler.step(opt_gen)
        g_scaler.update()
        
        if idx % 200 == 0:
            save_image(fake_horse * 0.5 + 0.5, f"saved_images/horse_{idx}.png") # to do the inverse of the normalization made in CycleGAN_config
            save_image(fake_zebra * 0.5 + 0.5, f"saved_images/zebra_{idx}.png")
def main():
    disc_H = Discriminator(in_channels=3).to(config.DEVICE) # Discriminator for Horses
    disc_Z = Discriminator(in_channels=3).to(config.DEVICE) # Discriminator for Zebras
    
    gen_H = Generator(img_channels=3, num_residuals=9).to(config.DEVICE) # Recives Horses and generates Zebras
    gen_Z = Generator(img_channels=3, num_residuals=9).to(config.DEVICE) # Recives Zebras and generates Horses
    
    opt_disc = optim.Adam(
        list(disc_H.parameters()) + list(disc_Z.parameters()),
        lr = config.LEARNING_RATE,
        betas = (0.5, 0.999),
    )
    opt_gen = optim.Adam(
        list(gen_Z.parameters()) + list(gen_H.parameters()),
        lr = config.LEARNING_RATE,
        betas = (0.5, 0.999)
    )
    
    L1 = nn.L1Loss() #  L1 for CycleLoss and identity loss
    mse = nn.MSELoss() # MSE for Adversarial Loss
    
    # Checking for loading checkpoint or not
    if config.LOAD_MODEL:
        load_checkpoint(
            config.CHECKPOINT_GEN_H,
            gen_H,
            opt_gen,
            config.LEARNING_RATE,
        )
        load_checkpoint(
            config.CHECKPOINT_GEN_Z,
            gen_Z,
            opt_gen,
            config.LEARNING_RATE,
        )
        load_checkpoint(
            config.CHECKPOINT_CRITIC_H,
            disc_H,
            opt_disc,
            config.LEARNING_RATE,
        )
        load_checkpoint(
            config.CHECKPOINT_CRITIC_Z,
            disc_Z,
            opt_disc,
            config.LEARNING_RATE,
        )
        
    dataset = HorseZebraDataset(
        root_horse=config.TRAIN_DIR + "/horses",
        root_zebra=config.TRAIN_DIR + "/zebras",
        transform=config.transforms,
    )
    val_dataset = HorseZebraDataset(
        root_horse=config.VAL_DIR + "/horses",
        root_zebra=config.VAL_DIR + "/zebras",
        transform=config.transforms,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=1,
        shuffle=False,
        pin_memory=True,
    )
    loader = DataLoader(
        dataset,
        batch_size=config.BATCH_SIZE,
        shuffle=True,
        num_workers=config.NUM_WORKERS,
        pin_memory=True,
    )
    g_scaler = torch.cuda.amp.GradScaler()
    d_scaler = torch.cuda.amp.GradScaler()

    for epoch in range(config.NUM_EPOCHS):
        train_fn(
            disc_H,
            disc_Z,
            gen_Z,
            gen_H,
            loader,
            opt_disc,
            opt_gen,
            L1,
            mse,
            d_scaler,
            g_scaler,
        )

        if config.SAVE_MODEL:
            save_checkpoint(gen_H, opt_gen, filename=config.CHECKPOINT_GEN_H)
            save_checkpoint(gen_Z, opt_gen, filename=config.CHECKPOINT_GEN_Z)
            save_checkpoint(disc_H, opt_disc, filename=config.CHECKPOINT_CRITIC_H)
            save_checkpoint(disc_Z, opt_disc, filename=config.CHECKPOINT_CRITIC_Z)


if __name__ == "__main__":
    main()
# Out:
#   0%|          | 0/1334 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/csuarezgurruchaga/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/csuarezgurruchaga/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/csuarezgurruchaga/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# ModuleNotFoundError: No module named 'CycleGAN_dataset'
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/csuarezgurruchaga/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# ModuleNotFoundError: No module named 'CycleGAN_dataset'
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/csuarezgurruchaga/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/csuarezgurruchaga/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# ModuleNotFoundError: No module named 'CycleGAN_dataset'
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/csuarezgurruchaga/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/csuarezgurruchaga/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# ModuleNotFoundError: No module named 'CycleGAN_dataset'
#   0%|          | 0/1334 [00:04<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/redes/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1134, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1133 try:
# -> 1134     data = self._data_queue.get(timeout=timeout)
#    1135     return (True, data)
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/queues.py:107, in Queue.get(self, block, timeout)
#     106 timeout = deadline - time.monotonic()
# --> 107 if not self._poll(timeout):
#     108     raise Empty
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/connection.py:424, in Connection._poll(self, timeout)
#     423 def _poll(self, timeout):
# --> 424     r = wait([self], timeout)
#     425     return bool(r)
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/site-packages/torch/utils/data/_utils/signal_handling.py:63, in _set_SIGCHLD_handler.<locals>.handler(signum, frame)
#      61     previous_handler = None
# ---> 63 def handler(signum, frame):
#      64     # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65     # Python can still get and update the process status successfully.
#      66     _error_if_any_worker_fails()
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/site-packages/torch/utils/data/_utils/signal_handling.py:66, in _set_SIGCHLD_handler.<locals>.handler(signum, frame)
#      63 def handler(signum, frame):
#      64     # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65     # Python can still get and update the process status successfully.
# ---> 66     _error_if_any_worker_fails()
#      67     if previous_handler is not None:
#
# RuntimeError: DataLoader worker (pid 58869) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb Cell 1 in <cell line: 182>()
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=178'>179</a>             save_checkpoint(disc_Z, opt_disc, filename=config.CHECKPOINT_CRITIC_Z)
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=181'>182</a> if __name__ == "__main__":
# --> <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=182'>183</a>     main()
#
# /Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb Cell 1 in main()
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=157'>158</a> d_scaler = torch.cuda.amp.GradScaler()
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=159'>160</a> for epoch in range(config.NUM_EPOCHS):
# --> <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=160'>161</a>     train_fn(
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=161'>162</a>         disc_H,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=162'>163</a>         disc_Z,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=163'>164</a>         gen_Z,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=164'>165</a>         gen_H,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=165'>166</a>         loader,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=166'>167</a>         opt_disc,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=167'>168</a>         opt_gen,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=168'>169</a>         L1,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=169'>170</a>         mse,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=170'>171</a>         d_scaler,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=171'>172</a>         g_scaler,
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=172'>173</a>     )
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=174'>175</a>     if config.SAVE_MODEL:
#     <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=175'>176</a>         save_checkpoint(gen_H, opt_gen, filename=config.CHECKPOINT_GEN_H)
#
# /Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb Cell 1 in train_fn(disc_H, disc_Z, gen_Z, gen_H, loader, opt_disc, opt_gen, L1, mse, d_scaler, g_scaler)
#      <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a> def train_fn(disc_H, disc_Z, gen_Z, gen_H, loader, opt_disc, opt_gen, L1, mse, d_scaler, g_scaler):
#      <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a>     loop = tqdm(loader, leave = True)
# ---> <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a>     for idx, (zebra, horse) in enumerate(loop):
#      <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a>         zebra = zebra.to(config.DEVICE)
#      <a href='vscode-notebook-cell:/Users/csuarezgurruchaga/Desktop/Deep_learning/GANs/CycleGAN_train.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a>         horse = horse.to(config.DEVICE)
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/site-packages/tqdm/std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/site-packages/torch/utils/data/dataloader.py:635, in _BaseDataLoaderIter.__next__(self)
#     632 if self._sampler_iter is None:
#     633     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     634     self._reset()  # type: ignore[call-arg]
# --> 635 data = self._next_data()
#     636 self._num_yielded += 1
#     637 if self._dataset_kind == _DatasetKind.Iterable and \
#     638         self._IterableDataset_len_called is not None and \
#     639         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1330, in _MultiProcessingDataLoaderIter._next_data(self)
#    1327     return self._process_data(data)
#    1329 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1330 idx, data = self._get_data()
#    1331 self._tasks_outstanding -= 1
#    1332 if self._dataset_kind == _DatasetKind.Iterable:
#    1333     # Check for _IterableDatasetStopIteration
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1296, in _MultiProcessingDataLoaderIter._get_data(self)
#    1292     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1293     # need to call `.task_done()` because we don't use `.join()`.
#    1294 else:
#    1295     while True:
# -> 1296         success, data = self._try_get_data()
#    1297         if success:
#    1298             return data
#
# File ~/opt/anaconda3/envs/redes/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1147, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1145 if len(failed_workers) > 0:
#    1146     pids_str = ', '.join(str(w.pid) for w in failed_workers)
# -> 1147     raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str)) from e
#    1148 if isinstance(e, queue.Empty):
#    1149     return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 58869, 58870, 58871) exited unexpectedly
